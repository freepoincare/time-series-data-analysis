# %% [markdown]
# # AI Data Analysis: Data-Driven Trend Analysis
#
# ## 1. Analysis Topic
# TODO

# %% [markdown]
# ## 2. Analysis Questions
#
# 1. TODO
# 2. TODO
# 3. TODO

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3. Load Data
#
# TODO

# %%
# Load raw data here
# df = pd.read_csv(...)

# %% [markdown]
# ## 4. Data Cleaning
#
# TODO: missing values, duplicates, outliers, date handling

# %% [markdown]
# ## 5. Time-Series Analysis
#
# ### Method 1
# TODO
#
# ### Method 2
# TODO

# %% [markdown]
# ## 6. Visualization
#
# Create at least two visualizations.

# %% [markdown]
# ## 7. Insights
#
# ### Insight 1
# - Observation:
# - Evidence:
# - Interpretation:
# - Action:
#
# ### Insight 2
# - Observation:
# - Evidence:
# - Interpretation:
# - Action:
#
# ### Insight 3
# - Observation:
# - Evidence:
# - Interpretation:
# - Action:

# %% [markdown]
# ## 8. Conclusion and Limitations
#
# TODO

# %% [markdown]
# ## 9. AI Usage Log
#
# | Task | Why AI was used | Verification |
# |---|---|---|
# | | | |
