# %% [markdown]
# ## 7. 탐색적 데이터 분석 (Exploratory Data Analysis)

# %% [markdown]
# ## 8. Time-Series Analysis
#
# ### Method 1
# TODO
#
# ### Method 2
# TODO

# %% [markdown]
# ## 6. Visualization
#
# Create at least two visualizations.

# %% [markdown]
# ## 7. Insights
#
# ### Insight 1
# - Observation:
# - Evidence:
# - Interpretation:
# - Action:
#
# ### Insight 2
# - Observation:
# - Evidence:
# - Interpretation:
# - Action:
#
# ### Insight 3
# - Observation:
# - Evidence:
# - Interpretation:
# - Action:

# %% [markdown]
# ## 8. Conclusion and Limitations
#
# TODO

# %% [markdown]
# ## 9. AI Usage Log
#
# | Task | Why AI was used | Verification |
# |---|---|---|
# | | | |
