# %% [markdown]
# ```text
# 1. Descriptive Analysis
#    ├── Annual temperature
#    ├── Summer/Winter temperature
#    ├── 35°C+ days
#    └── Monthly summer/winter-like ratios
#           ↓
# 2. Trend Analysis
#    ├── Moving Average
#    ├── Linear Regression
#    └── Mann-Kendall
#           ↓
# 3. Seasonal Expansion Analysis
#    ├── Summer transition months (May–September)
#    ├── Winter transition months (November–March)
#    └── Heatmaps ⭐
#           ↓
# 4. Forecasting
#    └── ARIMA
# ```
#
#
# ```text
# ────────────────────────────
# 1. Descriptive Analysis
# ────────────────────────────
#       ↓
# Annual / seasonal averages
# 35°C+ days
# Summer-like / winter-like days
#       ↓
# Visualization
#       ↓
# ────────────────────────────
# 2. Trend Analysis
# ────────────────────────────
# Moving Average
#       ↓
# Linear Regression
#       ↓
# Mann-Kendall Test
#       ↓
# Trend visualizations
#       ↓
# ────────────────────────────
# 3. Seasonal Expansion Analysis
# ────────────────────────────
# Monthly summer-like ratio
# Monthly winter-like ratio
#       ↓
# Heatmap / line graphs  (The heatmap is particularly valuable here because it can show year × month with the percentage of summer-like or winter-like days, making changes in May/September and November/March visually obvious.)
#       ↓
# ────────────────────────────
# 4. Future Prediction
# ────────────────────────────
# ARIMA
#       ↓
# 5-year summer temperature forecast
#       ↓
# Forecast graph
# ```

# %% [markdown]
# ## 6. Descriptive Analysis

# %% [markdown]
# ### 6.1. Annual temperature statistics
#
# First, calculate annual average, minimum, and maximum temperature.

# %% [markdown]
# ## 6. Visualization
#
# Create at least two visualizations.

# %% [markdown]
# ## 7. Insights
#
# ### Insight 1
# - Observation:
# - Evidence:
# - Interpretation:
# - Action:
#
# ### Insight 2
# - Observation:
# - Evidence:
# - Interpretation:
# - Action:
#
# ### Insight 3
# - Observation:
# - Evidence:
# - Interpretation:
# - Action:

# %% [markdown]
# ## 8. Conclusion and Limitations
#
# TODO

# %% [markdown]
# ## 9. AI Usage Log
#
# | Task | Why AI was used | Verification |
# |---|---|---|
# | | | |
